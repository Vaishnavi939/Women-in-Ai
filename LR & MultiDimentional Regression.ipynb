# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#from google.colab import drive
#drive.mount('content/drive')
#mount command only accepts folder input not 'csv'

# %%
df=pd.read_csv("/content/citizen_pci.csv")

# %%
df
# Out:
#     year           pci
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# 39  2009  32755.176820
# 40  2010  38420.522890
# 41  2011  42334.711210
# 42  2012  42665.255970
# 43  2013  42676.468370
# 44  2014  41039.893600
# 45  2015  35175.188980
# 46  2016  34229.193630

# %%
df.pci.unique()
# Out:
# array([ 3399.299037,  3768.297935,  4251.175484,  4804.463248,
#         5576.514583,  5998.144346,  7062.131392,  7100.12617 ,
#         7247.967035,  7602.912681,  8355.96812 ,  9434.390652,
#         9619.438377, 10416.53659 , 10790.32872 , 11018.95585 ,
#        11482.89153 , 12974.80662 , 15080.28345 , 16426.72548 ,
#        16838.6732  , 17266.09769 , 16412.08309 , 15875.58673 ,
#        15755.82027 , 16369.31725 , 16699.82668 , 17310.75775 ,
#        16622.67187 , 17581.02414 , 18987.38241 , 18601.39724 ,
#        19232.17556 , 22739.42628 , 25719.14715 , 29198.05569 ,
#        32738.2629  , 36144.48122 , 37446.48609 , 32755.17682 ,
#        38420.52289 , 42334.71121 , 42665.25597 , 42676.46837 ,
#        41039.8936  , 35175.18898 , 34229.19363 ])

# %%
df.pci.sort_values().head(5)
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: pci, dtype: float64

# %%
df.pci.value_counts().tail(10)
# Out:
# pci
# 10416.53659    1
# 10790.32872    1
# 11018.95585    1
# 11482.89153    1
# 12974.80662    1
# 15080.28345    1
# 16426.72548    1
# 16838.67320    1
# 17266.09769    1
# 34229.19363    1
# Name: count, dtype: int64

# %%
df.pci.value_counts().tail(10).plot()
# Out:
# <Axes: xlabel='pci'>

# %%
df.pci.sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.scatter(df.year,df.pci)
plt.xlabel('year')
plt.ylabel('pci')
plt.show()

# %%
import sklearn.linear_model as linear_model
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df.pci)
# Out:
# LinearRegression()

# %%
#dataset is two dimentional we should keep two square brackets
reg.predict([[2003]])
# Out:
# array([27204.78781563])

# %%
#its predicting pci values by the year
plt.scatter(df.year,df.pci)
plt.plot(df.year, reg.predict(df[['year']]), color='purple')
plt.xlabel('year')
plt.ylabel('pci')
plt.show()

# %%
df1=pd.read_csv("/content/Salary_Data.csv")

# %%
df1
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df1.Salary.max()
# Out:
# 122391

# %%
plt.scatter(df1.YearsExperience, df1.Salary)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
#its predicting pci values by the year
plt.scatter(df1.YearsExperience, df1.Salary)
#plt.plot(df1.YearsExperience, reg.predict(df1[['year']]), color='purple')
#reg.fit(df1[['YearsExperience']], df1.Salary)
df1.rename(columns={'YearsExperience': 'year'}, inplace=True)
reg.fit(df1[['year']], df1.Salary)
plt.plot(df1.year, reg.predict(df1[['year']]), color='purple')
plt.xlabel('YearsExperiencear')
plt.ylabel('Salary')
plt.show()

# %%
x=df1.iloc[:,:-1].values

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
df1.iloc[0]
# Out:
# year          1.1
# Salary    39343.0
# Name: 0, dtype: float64

# %%
df1.iloc[:10]
# Out:
#    year  Salary
# 0   1.1   39343
# 1   1.3   46205
# 2   1.5   37731
# 3   2.0   43525
# 4   2.2   39891
# 5   2.9   56642
# 6   3.0   60150
# 7   3.2   54445
# 8   3.2   64445
# 9   3.7   57189

# %%
df1.iloc[:10,-1]
# Out:
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# Name: Salary, dtype: int64

# %%
x = df1.iloc[:,:-1].values
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y = df1.iloc[:,-1].values
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
plt.plot(x,y,'c')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=1/3,random_state=10)

# %%
print("X Shape:", x.shape)
print("Y Shape:", y.shape)
print("x train:", x_train.shape)
print("x test:", x_test.shape)
print("y train:", y_train.shape)
print("y test:", y_test.shape)
# Out:
# X Shape: (30, 1)
# Y Shape: (30,)
# x train: (20, 1)
# x test: (10, 1)
# y train: (20,)
# y test: (10,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)#y=mx+c
print(regressor.intercept_)
print(regressor.coef_)
print(regressor)
# Out:
# 25630.510121837833
# [9514.52350354]
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([ 90329.26994588,  56076.98533315,  53222.62828209,  39902.29537714,
#         44659.55712891,  93183.62699694,  64640.05648633, 116969.93575577,
#         63688.60413598,  37999.39067643])

# %%
x_test
# Out:
# array([[6.8],
#        [3.2],
#        [2.9],
#        [1.5],
#        [2. ],
#        [7.1],
#        [4.1],
#        [9.6],
#        [4. ],
#        [1.3]])

# %%
df1_x_test=pd.DataFrame(x_test)
df1_y_test=pd.DataFrame(y_test)
df1_y_pred=pd.DataFrame(y_pred)
df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred], axis=1)
y_test_pred['Difference']=df1_diff

# %%
y_test_pred
# Out:
#      0       0              0   Difference
# 0  6.8   91738   90329.269946  1408.730054
# 1  3.2   54445   56076.985333 -1631.985333
# 2  2.9   56642   53222.628282  3419.371718
# 3  1.5   37731   39902.295377 -2171.295377
# 4  2.0   43525   44659.557129 -1134.557129
# 5  7.1   98273   93183.626997  5089.373003
# 6  4.1   57081   64640.056486 -7559.056486
# 7  9.6  112635  116969.935756 -4334.935756
# 8  4.0   56957   63688.604136 -6731.604136
# 9  1.3   46205   37999.390676  8205.609324

# %%
df1_x_test=pd.DataFrame(x_test,columns=['Experience'])
df1_y_test=pd.DataFrame(y_test,columns=['Salary'])
df1_y_pred=pd.DataFrame(y_pred,columns=['Prediction'])
df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred], axis=1)
y_test_pred['Difference']=y_test_pred['Salary']-y_test_pred['Prediction']
y_test_pred
# Out:
#    Experience  Salary     Prediction   Difference
# 0         6.8   91738   90329.269946  1408.730054
# 1         3.2   54445   56076.985333 -1631.985333
# 2         2.9   56642   53222.628282  3419.371718
# 3         1.5   37731   39902.295377 -2171.295377
# 4         2.0   43525   44659.557129 -1134.557129
# 5         7.1   98273   93183.626997  5089.373003
# 6         4.1   57081   64640.056486 -7559.056486
# 7         9.6  112635  116969.935756 -4334.935756
# 8         4.0   56957   63688.604136 -6731.604136
# 9         1.3   46205   37999.390676  8205.609324

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9602319713033924

# %%
y_pred_f=regressor.predict(x)
y_pred_f
# Out:
# array([ 36096.48597573,  37999.39067643,  39902.29537714,  44659.55712891,
#         46562.46182961,  53222.62828209,  54174.08063244,  56076.98533315,
#         56076.98533315,  60834.24708492,  62737.15178562,  63688.60413598,
#         63688.60413598,  64640.05648633,  68445.86588775,  72251.67528916,
#         74154.57998987,  76057.48469057,  81766.19879269,  82717.65114305,
#         90329.26994588,  93183.62699694, 100795.24579976, 103649.60285082,
#        108406.86460259, 111261.22165365, 116018.48340542, 116969.93575577,
#        123630.10220825, 125533.00690896])

# %%
y_pred_final=pd.DataFrame(y_pred_f,columns=['Prediction'])
y_pred_final
# Out:
#        Prediction
# 0    36096.485976
# 1    37999.390676
# 2    39902.295377
# 3    44659.557129
# 4    46562.461830
# 5    53222.628282
# 6    54174.080632
# 7    56076.985333
# 8    56076.985333
# 9    60834.247085
# 10   62737.151786
# 11   63688.604136
# 12   63688.604136
# 13   64640.056486
# 14   68445.865888
# 15   72251.675289
# 16   74154.579990
# 17   76057.484691
# 18   81766.198793
# 19   82717.651143
# 20   90329.269946
# 21   93183.626997
# 22  100795.245800
# 23  103649.602851
# 24  108406.864603
# 25  111261.221654
# 26  116018.483405
# 27  116969.935756
# 28  123630.102208
# 29  125533.006909

# %%
result = pd.concat([df1,y_pred_final],axis=1)
result
# Out:
#     year  Salary     Prediction
# 0    1.1   39343   36096.485976
# 1    1.3   46205   37999.390676
# 2    1.5   37731   39902.295377
# 3    2.0   43525   44659.557129
# 4    2.2   39891   46562.461830
# 5    2.9   56642   53222.628282
# 6    3.0   60150   54174.080632
# 7    3.2   54445   56076.985333
# 8    3.2   64445   56076.985333
# 9    3.7   57189   60834.247085
# 10   3.9   63218   62737.151786
# 11   4.0   55794   63688.604136
# 12   4.0   56957   63688.604136
# 13   4.1   57081   64640.056486
# 14   4.5   61111   68445.865888
# 15   4.9   67938   72251.675289
# 16   5.1   66029   74154.579990
# 17   5.3   83088   76057.484691
# 18   5.9   81363   81766.198793
# 19   6.0   93940   82717.651143
# 20   6.8   91738   90329.269946
# 21   7.1   98273   93183.626997
# 22   7.9  101302  100795.245800
# 23   8.2  113812  103649.602851
# 24   8.7  109431  108406.864603
# 25   9.0  105582  111261.221654
# 26   9.5  116969  116018.483405
# 27   9.6  112635  116969.935756
# 28  10.3  122391  123630.102208
# 29  10.5  121872  125533.006909

# %%
acc = r2_score(y,y_pred_f)
acc
# Out:
# 0.9568667319430351

# %%
regressor.predict([[5]])
# Out:
# array([73203.12763951])
